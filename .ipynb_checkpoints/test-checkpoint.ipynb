# %%
file_dir = '/ahc/work3/kosuke-t/data/WMT/newstest2017-system-level-human/anon-proc-hits-sys-combined/analysis'

import os
import re
import pickle

langs = ['cs-en','de-en','en-cs','en-de','en-fi','en-lv','en-ru',
         'en-tr','en-zh','fi-en','lv-en','ru-en','tr-en','zh-en']

# %%
def load_file(filename):
    if not os.path.isfile(filename):
        print('{} does not exist'.format(filename))
        exit(-2)
    data = []
    with open(filename, mode='r', encoding='utf-8') as r:
        data = r.read().split(os.linesep)
        if data[-1] == '':
            data.pop(-1)
    return data

# %%
da_files = {}
sys_dic = {}
corpus = {lang:[] for lang in langs}
times_dic = {lang:{} for lang in langs}
for lang in langs:
    da_files[lang] = load_file(os.path.join(file_dir, 'ad-seg-scores-{}.csv'.format(lang)))
    for idx, row in enumerate(da_files[lang]):
        if idx == 0:
            continue
        sys_id = row.split(' ')[0]
        sid = int(row.split(' ')[1])
        score = float(row.split(' ')[3])
        n = int(row.split(' ')[4])
        key = (lang, sys_id)
        if key not in sys_dic:
            sys_dic[key] = 1
        else:
            sys_dic[key] += 1
        
        corpus[lang].append({'lang':lang, 'sys_id':sys_id, 'sid':sid, 'label':score})
        
        if n not in times_dic[lang]:
            times_dic[lang][n] = 1
        else:
            times_dic[lang][n] += 1

# %%
filepath = '/ahc/work3/kosuke-t/data/WMT/DAseg-wmt-newstest2017/anon-proc-hits-seg-en/analysis/ad-seg-scores.csv'

langs = ['cs-en','de-en','fi-en','lv-en','ru-en','tr-en','zh-en']
SYSTEMS17 = {'cs-en':['online-A.0', 'online-B.0', 'PJATK.4760', 'uedin-nmt.4955'], 
             'de-en':['C-3MA.4958', 'online-A.0', 'online-G.0', 'TALP-UPC.4830', 
                      'KIT.4951', 'online-B.0', 'RWTH-nmt-ensemble.4920', 'uedin-nmt.4723',
                      'LIUM-NMT.4733', 'online-F.0', 'SYSTRAN.4846'], 
             'fi-en':['apertium-unconstrained.4793', 'online-A.0', 'online-G.0',
                      'Hunter-MT.4925', 'online-B.0', 'TALP-UPC.4937'], 
             'lv-en':['C-3MA.5067', 'online-A.0', 'tilde-c-nmt-smt-hybrid.5051',
                      'Hunter-MT.5092', 'online-B.0', 'tilde-nc-nmt-smt-hybrid.5050',
                      'jhu-pbmt.4980', 'PJATK.4740', 'uedin-nmt.5017'], 
             'ru-en':['afrl-mitll-opennmt.4896', 'jhu-pbmt.4978', 'online-A.0', 
                      'online-F.0', 'uedin-nmt.4890', 'afrl-mitll-syscomb.4905',
                      'NRC.4855', 'online-B.0', 'online-G.0'], 
             'tr-en':['afrl-mitll-m2w-nr1.4901', 'JAIST.4859', 'LIUM-NMT.4888',
                      'online-B.0', 'PROMT-SMT.4737', 'afrl-mitll-syscomb.4902',
                      'jhu-pbmt.4972', 'online-A.0', 'online-G.0', 'uedin-nmt.4931'], 
             'zh-en':['afrl-mitll-opennmt.5109', 'NRC.5172', 'online-G.0',
                      'SogouKnowing-nmt.5171', 'CASICT-DCU-NMT.5144', 'online-A.0',
                      'Oregon-State-University-S.5173', 'uedin-nmt.5112', 'jhu-nmt.5151', 
                      'online-B.0', 'PROMT-SMT.5125', 'UU-HNMT.5162',
                      'NMT-Model-Average-Multi-Cards.5099', 'online-F.0', 'ROCMT.5183', 'xmunmt.5160']
            }
data = load_file(filepath)
sys_dic = {}
corpus = {lang:[] for lang in langs}
times_dic = {lang:{} for lang in langs}
for idx, row in enumerate(data):
    if idx == 0:
        continue
    lang = '{}-{}'.format(row.split(' ')[0], row.split(' ')[1])
    hit = int(row.split(' ')[2])
    n = int(row.split(' ')[4])
    sid = int(row.split(' ')[5])
    sys_id = row.split(' ')[6]
    score = row.split(' ')[8]
    key = (lang, sys_id)
    
    if sys_id not in SYSTEMS17[lang]:
        continue
    if key not in sys_dic:
        sys_dic[key] = 1
    else:
        sys_dic[key] += 1

    corpus[lang].append({'lang':lang, 'sys_id':sys_id, 'sid':sid, 'label':score})

    if n not in times_dic[lang]:
        times_dic[lang][n] = 1
    else:
        times_dic[lang][n] += 1

# %%
sys_dic
# Out:
# {('cs-en', 'online-A.0'): 131,
#  ('cs-en', 'PJATK.4760'): 151,
#  ('cs-en', 'online-B.0'): 127,
#  ('cs-en', 'uedin-nmt.4955'): 132,
#  ('cs-en', 'uedin-nmt.4955+PJATK.4760'): 1,
#  ('cs-en', 'PJATK.4760+online-B.0'): 2,
#  ('cs-en', 'PJATK.4760+online-A.0'): 3,
#  ('cs-en', 'online-A.0+online-B.0'): 4,
#  ('cs-en', 'uedin-nmt.4955+PJATK.4760+online-A.0'): 2,
#  ('cs-en', 'uedin-nmt.4955+PJATK.4760+online-A.0+online-B.0'): 4,
#  ('cs-en', 'uedin-nmt.4955+online-A.0'): 2,
#  ('cs-en', 'uedin-nmt.4955+online-B.0'): 1,
#  ('de-en', 'online-F.0'): 55,
#  ('de-en', 'SYSTRAN.4846'): 49,
#  ('de-en', 'C-3MA.4958+KIT.4951'): 1,
#  ('de-en', 'online-B.0+C-3MA.4958+LIUM-NMT.4733'): 1,
#  ('de-en', 'TALP-UPC.4830+uedin-nmt.4723'): 1,
#  ('de-en', 'LIUM-NMT.4733'): 50,
#  ('de-en', 'online-A.0'): 44,
#  ('de-en', 'KIT.4951'): 45,
#  ('de-en', 'C-3MA.4958'): 51,
#  ('de-en', 'TALP-UPC.4830'): 52,
#  ('de-en', 'RWTH-nmt-ensemble.4920'): 37,
#  ('de-en', 'uedin-nmt.4723'): 46,
#  ('de-en', 'online-G.0'): 54,
#  ('de-en', 'SYSTRAN.4846+uedin-nmt.4723+online-A.0'): 1,
#  ('de-en', 'SYSTRAN.4846+online-B.0+TALP-UPC.4830+KIT.4951'): 1,
#  ('de-en', 'online-B.0'): 51,
#  ('de-en', 'SYSTRAN.4846+uedin-nmt.4723'): 1,
#  ('de-en', 'uedin-nmt.4723+KIT.4951'): 2,
#  ('de-en', 'RWTH-nmt-ensemble.4920+KIT.4951'): 2,
#  ('de-en',
#   'SYSTRAN.4846+online-B.0+RWTH-nmt-ensemble.4920+TALP-UPC.4830+C-3MA.4958+online-A.0+LIUM-NMT.4733'): 1,
#  ('de-en', 'uedin-nmt.4723+online-A.0'): 1,
#  ('de-en', 'C-3MA.4958+online-A.0'): 1,
#  ('de-en', 'RWTH-nmt-ensemble.4920+online-A.0'): 1,
#  ('de-en',
#   'SYSTRAN.4846+online-B.0+RWTH-nmt-ensemble.4920+uedin-nmt.4723+C-3MA.4958+online-A.0+LIUM-NMT.4733+KIT.4951'): 1,
#  ('de-en', 'RWTH-nmt-ensemble.4920+uedin-nmt.4723'): 1,
#  ('de-en',
#   'SYSTRAN.4846+online-B.0+RWTH-nmt-ensemble.4920+uedin-nmt.4723+online-A.0+LIUM-NMT.4733+KIT.4951'): 1,
#  ('de-en', 'SYSTRAN.4846+KIT.4951'): 1,
#  ('de-en', 'online-B.0+online-A.0'): 1,
#  ('de-en',
#   'online-B.0+RWTH-nmt-ensemble.4920+TALP-UPC.4830+uedin-nmt.4723+C-3MA.4958+online-A.0+LIUM-NMT.4733+online-F.0+KIT.4951'): 1,
#  ('de-en',
#   'SYSTRAN.4846+RWTH-nmt-ensemble.4920+online-G.0+TALP-UPC.4830+uedin-nmt.4723+C-3MA.4958+KIT.4951'): 1,
#  ('de-en',
#   'online-B.0+RWTH-nmt-ensemble.4920+TALP-UPC.4830+uedin-nmt.4723'): 1,
#  ('de-en', 'TALP-UPC.4830+online-A.0'): 1,
#  ('de-en', 'online-B.0+uedin-nmt.4723'): 1,
#  ('de-en', 'online-B.0+RWTH-nmt-ensemble.4920+uedin-nmt.4723+KIT.4951'): 1,
#  ('de-en', 'TALP-UPC.4830+LIUM-NMT.4733'): 1,
#  ('fi-en', 'online-B.0'): 94,
#  ('fi-en', 'TALP-UPC.4937'): 94,
#  ('fi-en', 'apertium-unconstrained.4793'): 100,
#  ('fi-en', 'Hunter-MT.4925'): 99,
#  ('fi-en', 'online-A.0'): 76,
#  ('fi-en', 'online-G.0'): 88,
#  ('fi-en', 'online-A.0+online-G.0'): 3,
#  ('fi-en', 'online-B.0+TALP-UPC.4937'): 2,
#  ('fi-en', 'Hunter-MT.4925+online-B.0'): 1,
#  ('fi-en', 'online-B.0+online-G.0'): 1,
#  ('fi-en', 'online-A.0+Hunter-MT.4925+online-G.0'): 1,
#  ('fi-en', 'Hunter-MT.4925+online-G.0'): 1,
#  ('lv-en', 'PJATK.4740'): 60,
#  ('lv-en', 'tilde-nc-nmt-smt-hybrid.5050'): 62,
#  ('lv-en', 'jhu-pbmt.4980'): 65,
#  ('lv-en', 'uedin-nmt.5017'): 60,
#  ('lv-en',
#   'uedin-nmt.5017+online-A.0+tilde-c-nmt-smt-hybrid.5051+tilde-nc-nmt-smt-hybrid.5050'): 1,
#  ('lv-en', 'Hunter-MT.5092'): 58,
#  ('lv-en', 'online-B.0'): 61,
#  ('lv-en', 'online-A.0'): 66,
#  ('lv-en', 'tilde-c-nmt-smt-hybrid.5051'): 63,
#  ('lv-en', 'C-3MA.5067'): 55,
#  ('lv-en', 'uedin-nmt.5017+tilde-nc-nmt-smt-hybrid.5050'): 1,
#  ('lv-en',
#   'online-B.0+tilde-c-nmt-smt-hybrid.5051+tilde-nc-nmt-smt-hybrid.5050'): 1,
#  ('lv-en', 'Hunter-MT.5092+jhu-pbmt.4980'): 1,
#  ('lv-en',
#   'uedin-nmt.5017+online-B.0+Hunter-MT.5092+jhu-pbmt.4980+PJATK.4740+C-3MA.5067'): 1,
#  ('lv-en',
#   'uedin-nmt.5017+online-B.0+tilde-c-nmt-smt-hybrid.5051+C-3MA.5067'): 1,
#  ('lv-en', 'jhu-pbmt.4980+PJATK.4740'): 1,
#  ('lv-en', 'uedin-nmt.5017+C-3MA.5067'): 1,
#  ('lv-en', 'online-B.0+tilde-nc-nmt-smt-hybrid.5050+C-3MA.5067'): 1,
#  ('lv-en', 'online-B.0+tilde-nc-nmt-smt-hybrid.5050'): 1,
#  ('ru-en', 'online-A.0'): 62,
#  ('ru-en', 'online-F.0'): 64,
#  ('ru-en', 'uedin-nmt.4890'): 54,
#  ('ru-en',
#   'jhu-pbmt.4978+online-G.0+uedin-nmt.4890+afrl-mitll-opennmt.4896+online-A.0+NRC.4855+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en', 'online-G.0'): 63,
#  ('ru-en', 'NRC.4855'): 61,
#  ('ru-en', 'online-B.0'): 51,
#  ('ru-en', 'afrl-mitll-syscomb.4905'): 54,
#  ('ru-en', 'jhu-pbmt.4978'): 67,
#  ('ru-en', 'afrl-mitll-opennmt.4896'): 59,
#  ('ru-en', 'online-F.0+online-B.0'): 1,
#  ('ru-en', 'online-B.0+uedin-nmt.4890+afrl-mitll-opennmt.4896+online-A.0'): 1,
#  ('ru-en', 'jhu-pbmt.4978+afrl-mitll-opennmt.4896'): 1,
#  ('ru-en', 'online-B.0+online-A.0'): 1,
#  ('ru-en', 'NRC.4855+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en',
#   'online-F.0+online-B.0+afrl-mitll-opennmt.4896+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en', 'online-G.0+uedin-nmt.4890+afrl-mitll-opennmt.4896+NRC.4855'): 1,
#  ('ru-en',
#   'uedin-nmt.4890+afrl-mitll-opennmt.4896+NRC.4855+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en',
#   'online-B.0+afrl-mitll-opennmt.4896+NRC.4855+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en', 'afrl-mitll-opennmt.4896+NRC.4855+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en',
#   'online-G.0+uedin-nmt.4890+afrl-mitll-opennmt.4896+NRC.4855+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en',
#   'online-B.0+uedin-nmt.4890+afrl-mitll-opennmt.4896+NRC.4855+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en', 'afrl-mitll-opennmt.4896+afrl-mitll-syscomb.4905'): 4,
#  ('ru-en', 'online-B.0+online-G.0'): 1,
#  ('ru-en', 'jhu-pbmt.4978+NRC.4855'): 1,
#  ('ru-en', 'uedin-nmt.4890+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en', 'online-G.0+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en', 'jhu-pbmt.4978+NRC.4855+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en', 'online-B.0+NRC.4855'): 1,
#  ('ru-en', 'online-B.0+afrl-mitll-syscomb.4905'): 1,
#  ('ru-en', 'online-G.0+uedin-nmt.4890+afrl-mitll-syscomb.4905'): 1,
#  ('tr-en', 'online-A.0'): 42,
#  ('tr-en', 'afrl-mitll-syscomb.4902+afrl-mitll-m2w-nr1.4901'): 15,
#  ('tr-en', 'PROMT-SMT.4737'): 59,
#  ('tr-en', 'uedin-nmt.4931'): 59,
#  ('tr-en', 'online-G.0'): 61,
#  ('tr-en', 'JAIST.4859'): 63,
#  ('tr-en', 'afrl-mitll-m2w-nr1.4901'): 47,
#  ('tr-en', 'online-A.0+online-B.0'): 1,
#  ('tr-en', 'afrl-mitll-syscomb.4902'): 41,
#  ('tr-en', 'online-B.0'): 55,
#  ('tr-en', 'LIUM-NMT.4888'): 47,
#  ('tr-en', 'jhu-pbmt.4972'): 66,
#  ('tr-en', 'afrl-mitll-m2w-nr1.4901+online-B.0+online-G.0'): 1,
#  ('tr-en', 'jhu-pbmt.4972+JAIST.4859'): 2,
#  ('tr-en', 'online-B.0+LIUM-NMT.4888'): 1,
#  ('zh-en', 'CASICT-cons.5144'): 26,
#  ('zh-en', 'online-G.0'): 34,
#  ('zh-en', 'NRC.5172'): 32,
#  ('zh-en', 'online-A.0'): 29,
#  ('zh-en', 'Oregon-State-University-S.5173'): 32,
#  ('zh-en', 'online-B.0'): 32,
#  ('zh-en', 'SogouKnowing-nmt.5171'): 44,
#  ('zh-en', 'uedin-nmt.5112'): 40,
#  ('zh-en', 'xmunmt.5160+uedin-nmt.5112'): 2,
#  ('zh-en', 'xmunmt.5160'): 29,
#  ('zh-en', 'online-F.0'): 39,
#  ('zh-en', 'UU-HNMT.5162'): 29,
#  ('zh-en', 'jhu-nmt.5151'): 35,
#  ('zh-en', 'afrl-mitll-opennmt.5109'): 34,
#  ('zh-en', 'ROCMT.5167'): 25,
#  ('zh-en', 'CASICT-cons.5144+ROCMT.5167'): 8,
#  ('zh-en', 'NMT-Model-Average-Multi-Cards.5099'): 33,
#  ('zh-en', 'PROMT-SMT.5125'): 49,
#  ('zh-en', 'xmunmt.5160+NRC.5172+uedin-nmt.5112'): 1,
#  ('zh-en', 'xmunmt.5160+NRC.5172'): 1,
#  ('zh-en', 'jhu-nmt.5151+xmunmt.5160'): 1,
#  ('zh-en', 'SogouKnowing-nmt.5171+uedin-nmt.5112'): 1,
#  ('zh-en', 'xmunmt.5160+online-B.0'): 1,
#  ('zh-en', 'jhu-nmt.5151+xmunmt.5160+online-B.0'): 1,
#  ('zh-en', 'SogouKnowing-nmt.5171+afrl-mitll-opennmt.5109'): 1,
#  ('zh-en', 'xmunmt.5160+afrl-mitll-opennmt.5109+uedin-nmt.5112'): 1}
